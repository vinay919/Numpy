# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array1 = np.array([[1,2,3],
                   [4,5,6]])
array2 = np.random.rand(3,3)
array3 = np.zeros((4,4))

# %% [markdown]
# ## Save array physically in Array directory

# %%
np.save("./Array/Array1.npy",array1)
np.save("./Array/Array2.npy",array2)
np.save("./Array/Array3.npy",array3)

# %%
load_array1 = np.load("./Array/Array1.npy")
print(load_array1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
try:
    logo = np.load("numpy logo.npy")

    # Display
    plt.figure(figsize=(10,5))
    plt.subplot(121)
    plt.imshow(logo)
    plt.title("Numpy logo")
    plt.grid(False)

    dark_logo = 1 - logo
    plt.subplot(122)
    plt.imshow(dark_logo)
    plt.title("Numpy dark logo")
    plt.grid(False)

except:
    print("numpy logo file not found")
